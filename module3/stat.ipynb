# %%
import statistics as st

li = [1,2,3,4,5,6,7,8,9]
st.mean(li)
# Out:
# 5

# %%
import statistics as st

li = [10,20,30,40,40,60,40]
st.median(li)
st.quantiles(li)
# Out:
# [20.0, 40.0, 40.0]

# %%
import statistics as st

li = [4,4,6,8,9,1,1,1,6,7]
st.mode(li)

# %%
import statistics as st

li = [4,4,6,8,9,1,1,1,6,7]
st.mode(li)
# Out:
# 1

# %%
from math import sqrt 
# given data
x=[-2,-1,1,4,6,8]
N=len(x)
Mu= sum(x)/N  # 4.4
x_mu =0
for i in x:
    x_mu = x_mu +  (i-Mu)**2
prfloat("x-Mu:",x_mu)  # 21.2
    
Sigma = sqrt( (x_mu)/N )
prfloat("Standard Deviation:",Sigma)
# 1.9148542155126762

# %%
import pandas 
import matplotlib.pyplot as plt

data =[['EMP001','M',34,123,'Normal',350],['EMP002','F',25,124,'Normal',300],
       ['EMP003','M',39,150,'Normal',350],
       ['EMP006','M',39,160,'Normal',350],
       ['EMP007','M',39,165,'Normal',250],
       ['EMP004','M',29,110,'Obesity',150],
       ['EMP005','F',23,140,'Underweight',300],
       ['EMP005','F',23,129,'Underweight',300],]

dataframe= pandas.DataFrame(data,columns = ['Name','Gender','Age','Sales','BMI','income'])
dataframe.hist()
plt.show()

# %%
dataframe.plot.bar()
plt.show()

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
database=[]
column_names_list=[]
i=0
with open("csvfiles/adm_data.csv","r") as file_handler:
    data= csv.reader(file_handler)
    
    for line in data:
        # prfloat(line)
        if i==0 and i<11:
            
            column_names_list.append(line)
            i=i+1
            continue
        Int_list=[float(line[0]),float(line[1]),float(line[2]),float(line[3]),float(line[4]),float(line[5]),float(line[6]),float(line[7]),float(line[8])]
        database.append(Int_list)

print(column_names_list[0])
df= pd.DataFrame(database,columns=column_names_list[0])
df.plot.bar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 7
#       5 column_names_list=[]
#       6 i=0
# ----> 7 with open("csvfiles/adm_data.csv","r") as file_handler:
#       8     data= csv.reader(file_handler)
#      10     for line in data:
#      11         # prfloat(line)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'csvfiles/adm_data.csv'

# %%
#box plt

import pandas 
import matplotlib.pyplot as plt

data =[['EMP001','M',70,123,'Normal',350],['EMP002','F',25,124,'Normal',300],
       ['EMP003','M',39,150,'Normal',360],
       ['EMP006','M',50,160,'Normal',320],
       ['EMP007','M',45,165,'Normal',250],
       ['EMP004','M',35,110,'Obesity',150],
       ['EMP005','F',20,140,'Underweight',300],
       ['EMP005','F',23,129,'Underweight',300],]

dataframe= pandas.DataFrame(data,columns = ['Name','Gender','Age','Sales','BMI','income'])
dataframe.plot.box()
plt.show()

# %%
list=[40,50,80,70,20,90]
height=[4.2,4.5,5,5.5,4,4.8]
plt.pie(list,labels={"kannada","english","hindi","maths","science","sst"},autopct='%1.1f%%',shadow=True,radius=1)
plt.show()

# %%
income=[30000,35000,40000,42000,48000,55000,62000,66000,70000]
age=[20,30,40,42,45,50,60,70,80]
plt.scatter(age,income,color="red",edgecolor="green",linewidths=1,cmap="age")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
# Out:
# C:\Users\User4\AppData\Local\Temp\ipykernel_14312\3995023038.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(age,income,color="red",edgecolor="green",linewidths=1,cmap="age")

# %%
# dataset-1
x1 = [89, 43, 36, 36, 95, 10, 66, 34, 38, 20]
 
y1 = [21, 46, 3, 35, 67, 95,      53, 72, 58, 10]
 
# dataset2
x2 = [26, 29, 48, 64, 6, 5,      36, 66, 72, 40]
 
y2 = [26, 34, 90, 33, 38,      20, 56, 2, 47, 15]

plt.scatter(x1,y1,c="magenta",marker="s",s=10)
plt.scatter(x2,y2,c="blue",marker="d",s=60)
plt.show()
